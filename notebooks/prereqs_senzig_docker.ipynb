# %% [markdown]
# # SENZING pre-work
#
# - set up of Senzing, Postgres and Neo4j containers is captured in `docker-compose-senzing`
# - using `.env` file to capture Senzing and Postgres environment settings

# %% [markdown]
# ### check running docker containers

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %% [markdown]
# ### start docker compose network

# %%
# !pwd
# Out:
# /home/donbr/erkg_demo/notebooks

# %%
# !docker compose -f ../docker-compose-senzing.yml up -d
# Out:
# [+] Running 3/0
#  ✔ Network erkg_demo_senzing_network  Created                              0.0s
#  ✔ Volume "erkg_demo_neo4j_data"      C...                                 0.0s
#  ✔ Volume "erkg_demo_postgres_data"   Created                              0.0s
#  ⠋ Container portainer                Creating                             0.0s
#  ⠋ Container pgadmin                  Creating                             0.0s
#  ⠋ Container senzingapi-tools         Crea...                              0.0s
#  ⠋ Container postgres                 Creating                             0.0s
#  ⠋ Container neo4j                    Creating                             0.0s
# [+] Running 3/8
#  ✔ Network erkg_demo_senzing_network  Created                              0.0s
#  ✔ Volume "erkg_demo_neo4j_data"      C...                                 0.0s
#  ✔ Volume "erkg_demo_postgres_data"   Created                              0.0s
# ...

# %% [markdown]
# ### view docker logs for network

# %%
# !docker compose -f ../docker-compose-senzing.yml logs
# Out:
# postgres  | The files belonging to this database system will be owned by user "postgres".
# postgres  | This user must also own the server process.
# postgres  |
# postgres  | The database cluster will be initialized with locale "en_US.utf8".
# postgres  | The default database encoding has accordingly been set to "UTF8".
# postgres  | The default text search configuration will be set to "english".
# postgres  |
# postgres  | Data page checksums are disabled.
# postgres  |
# postgres  | fixing permissions on existing directory /var/lib/postgresql/data ... ok
# postgres  | creating subdirectories ... ok
# postgres  | selecting dynamic shared memory implementation ... posix
# postgres  | selecting default "max_connections" ... 100
# postgres  | selecting default "shared_buffers" ... 128MB
# postgres  | selecting default time zone ... America/Los_Angeles
# postgres  | creating configuration files ... ok
# postgres  | running bootstrap script ... ok
# ...

# %% [markdown]
# ### shutdown docker compose network

# %%
# !docker compose -f ../docker-compose-senzing.yml down -v
# Out:
# [+] Running 0/0
#  ⠋ Container pgadmin           Stopping                                    0.0s
#  ⠋ Container senzingapi-tools  Stopping                                    0.0s
#  ⠋ Container neo4j             Stopping                                    0.0s
#  ⠋ Container portainer         Stopping                                    0.0s
#  ⠋ Container web-app-demo      Stopping                                    0.0s
# [+] Running 0/5
#  ⠙ Container pgadmin           Stopping                                    0.1s
#  ⠙ Container senzingapi-tools  Stopping                                    0.1s
#  ⠙ Container neo4j             Stopping                                    0.1s
#  ⠙ Container portainer         Stopping                                    0.1s
#  ⠙ Container web-app-demo      Stopping                                    0.1s
# [+] Running 0/5
#  ⠹ Container pgadmin           Stopping                                    0.2s
# ...
