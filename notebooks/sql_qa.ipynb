# %%
# !pip install -q sqlalchemy langchain_openai langchain_community numpy
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import json
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

from langchain_openai import ChatOpenAI
from langchain_community.agent_toolkits import create_sql_agent
from langchain_community.utilities import SQLDatabase

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ## Import data
#
# This data set is the same data that was used by Paco Nathan in his [blog post](https://neo4j.com/developer-blog/entity-resolved-knowledge-graphs/) on entity-resolved knowledge graphs.  It is a combination of 3 files:
#
# 1. SafeGraph: a dataset of places of interest such as businesses and organizations
# 2. US Department of Labor Wage and Hour Compliance Action Data (DOL_WHISARD): a publicly-available dataset of labor violations of various companies
# 3. US Small Business Administration PPP Loans over $150K (PPP_LOANS): a publicly-available data set of Paycheck Protection Program (PPP) was a federal loans awarded to help small businesses keep their employees during the COVID-19 pandemic
#
# These files are available for download [here](https://senzing.com/get-erkg-tutorial-evaluation-data/).

# %%
sg_data = []

with open('./SafeGraph_LasVegas_Partial.json') as f:
    for line in f:
        sg_data.append(json.loads(line))

sg_df = pd.DataFrame(sg_data)

dol_data = []

with open('./Dept_Labor_Whisard_LasVegas.json') as f:
    for line in f:
        dol_data.append(json.loads(line))

dol_df = pd.DataFrame(dol_data)
dol_df = dol_df.iloc[:, :13]  # Each individual infraction count is shown beyond column 13

ppp_data = []

with open('./PPP_Loans_Over_150k_LasVegas.json') as f:
    for line in f:
        ppp_data.append(json.loads(line))

ppp_df = pd.DataFrame(ppp_data)

dol_df.replace('null', np.nan, inplace=True)

sg_df.shape, dol_df.shape, ppp_df.shape
# Out:
# ((79946, 25), (1554, 13), (3488, 19))

# %% [markdown]
# ## Querying tabular data
#
# I had originally tried to use the Pandas agent from LangChain but did not have much luck with it.  So I therefore elected to stand up a quickie little SQLite database.  My brief experiment here led me to conclude that the SQL agent for LangChain was a bit more reliable.

# %%
engine = create_engine("sqlite:///erkg_demo_sql.db")
sg_df.to_sql("sg", engine, index=False)
ppp_df.to_sql("ppp", engine, index=False)
dol_df.to_sql("dol", engine, index=False)
# Out:
# 1554

# %% [markdown]
# ### Verifying the SQL connection with LangChain...

# %%
db = SQLDatabase(engine=engine)

print(db.dialect)
print(db.get_usable_table_names())
print(db.run("SELECT count(*) FROM sg;"))
print(db.run("SELECT count(*) FROM ppp;"))
print(db.run("SELECT count(*) FROM dol;"))
# Out:
# sqlite
# ['dol', 'ppp', 'sg']
# [(79946,)]
# [(3488,)]
# [(1554,)]

# %%
sql_agent_executor = create_sql_agent(
    ChatOpenAI(temperature=0, model="gpt-4o-mini"), 
    db=db, 
    agent_type="openai-tools", 
    verbose=True
)

# %% [markdown]
# ## Let's get to work asking some questions!
#
# First, let's just see that the SQL agent can handle some basic data ops questions.

# %%
sql_agent_executor.invoke('what tables are present?')
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# dol, ppp, sg
# Invoking: `sql_db_schema` with `{'table_names': 'dol'}`
#
#
#
# CREATE TABLE dol (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	case_id TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"LEGAL_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	naic_cd TEXT,
# 	naics_code_description TEXT,
# 	case_violtn_cnt TEXT
# )
#
# /*
# 3 rows from dol table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	case_id	BUSINESS_NAME_ORG	LEGAL_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	naic_cd	naics_code_description	case_violtn_cnt
# ORGANIZATION	DoL_WHISARD	53	1658108	Fabulous Freddy's (Trailwood)	Fabulous LLC	9611 Trail Wood Drive	Las Vegas	NV	89134	811192	Car Washes	0
# ORGANIZATION	DoL_WHISARD	165	1419689	Boulder Station Hotel & Casino	Boulder Station, Inc.	4111 Boulder Hwy	Las Vegas	NV	89121	721120	Casino Hotels	1
# ORGANIZATION	DoL_WHISARD	178	1424856	MSI Landscaping	MIST Systems International, Inc.	4820 Quality Court, #B	Las Vegas	NV	89103	561730	Landscaping Services	14
# */
# Invoking: `sql_db_schema` with `{'table_names': 'ppp'}`
#
#
#
# CREATE TABLE ppp (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"Loan_Range" TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	"NAICS_Code" TEXT,
# 	"Business_Type" TEXT,
# 	"OwnedByRaceEthnicity" TEXT,
# 	"OwnedBy" TEXT,
# 	"OwnedByVeteran" TEXT,
# 	"NonProfit" TEXT,
# 	"JobsReported" TEXT,
# 	"DateApproved" TEXT,
# 	"Lender" TEXT,
# 	"CD" TEXT
# )
#
# /*
# 3 rows from ppp table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	Loan_Range	BUSINESS_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	NAICS_Code	Business_Type	OwnedByRaceEthnicity	OwnedBy	OwnedByVeteran	NonProfit	JobsReported	DateApproved	Lender	CD
# ORGANIZATION	PPP_LOANS	7017	c $1-2 million	INFINITY HOSPICE CARE OF LAS VEGAS, LLC	5110 N 40TH ST STE 107	PHOENIX	AZ	85018	623110	Limited  Liability Company(LLC)	Unanswered	Male Owned	Unanswered		137	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7018	d $350,000-1 million	CLUB TATTOO LAS VEGAS LLC	1839 s. almaschool rd. ste 230	MESA	AZ	85210	812199	Limited  Liability Company(LLC)	Unanswered	Male Owned	Non-Veteran		15	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7021	d $350,000-1 million	LAS VEGAS LABOR, LLC	10265 W Camelback Rd, Ste 104	PHOENIX	AZ	85037	111421	Limited  Liability Company(LLC)	Unanswered	Unanswered	Unanswered		0	04/07/2020	UMB Bank, National Association	AZ-03
# */
# Invoking: `sql_db_schema` with `{'table_names': 'sg'}`
#
#
#
# CREATE TABLE sg (
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"RECORD_TYPE" TEXT,
# 	"PLACEKEY" TEXT,
# 	"REL_ANCHOR_DOMAIN" TEXT,
# 	"REL_ANCHOR_KEY" TEXT,
# 	"LOCATION_NAME_ORG" TEXT,
# 	"BRANDS" TEXT,
# 	"TOP_CATEGORY" TEXT,
# 	"SUB_CATEGORY" TEXT,
# 	"NAICS_CODE" TEXT,
# 	"BUSINESS_GEO_LATITUDE" TEXT,
# 	"BUSINESS_GEO_LONGITUDE" TEXT,
# 	"CATEGORY_TAGS" TEXT,
# 	"CLOSED_ON" TEXT,
# 	"TRACKING_CLOSED_SINCE" TEXT,
# 	"PHONE_NUMBER" TEXT,
# 	"BUSINESS_ADDR_COUNTRY" TEXT,
# 	"BUSINESS_ADDR_FULL" TEXT,
# 	"MAILING_VERIFIED_STATUS" TEXT,
# 	"REL_POINTER_DOMAIN" TEXT,
# 	"REL_POINTER_KEY" TEXT,
# 	"REL_POINTER_ROLE" TEXT,
# 	"OPENED_ON" TEXT,
# 	"IS_INTERSECTION" TEXT
# )
#
# /*
# 3 rows from sg table:
# DATA_SOURCE	RECORD_ID	RECORD_TYPE	PLACEKEY	REL_ANCHOR_DOMAIN	REL_ANCHOR_KEY	LOCATION_NAME_ORG	BRANDS	TOP_CATEGORY	SUB_CATEGORY	NAICS_CODE	BUSINESS_GEO_LATITUDE	BUSINESS_GEO_LONGITUDE	CATEGORY_TAGS	CLOSED_ON	TRACKING_CLOSED_SINCE	PHONE_NUMBER	BUSINESS_ADDR_COUNTRY	BUSINESS_ADDR_FULL	MAILING_VERIFIED_STATUS	REL_POINTER_DOMAIN	REL_POINTER_KEY	REL_POINTER_ROLE	OPENED_ON	IS_INTERSECTION
# SAFEGRAPH	225-222@5yv-j92-tn5	ORGANIZATION	225-222@5yv-j92-tn5	PLACEKEY	225-222@5yv-j92-tn5	Cantwell Michelle L Atty	[]	Legal Services	Offices of Lawyers	541110	36.145647	-115.186399	[]	2024-02-01	2019-07-01	+17023627800	US	3320 W Sahara Ave Las Vegas NV 89102-3223	VERIFIED_PREMISE	None	None	None	None	None
# SAFEGRAPH	226-222@5yv-hmm-whq	ORGANIZATION	226-222@5yv-hmm-whq	PLACEKEY	226-222@5yv-hmm-whq	Pieology Pizzeria	[ { "safegraph_brand_id": "SG_BRAND_f372f9969f6e1ae119a13ff4fc78fd2d", "safegraph_brand_name": "Pieo	Restaurants and Other Eating Places	Limited-Service Restaurants	722513	36.144906	-115.332644	[ "Counter Service", "Dinner", "Fast Food", "Lunch", "Pizza" ]	None	2019-07-01	+17023314454	US	10965 Lavender Hill Dr Ste 130 Las Vegas NV 89135-2951	VERIFIED_DELIVERY_POINT	PLACEKEY	zzw-223@5yv-hkm-rc5	PARENT	None	None
# SAFEGRAPH	22s-222@5yv-jbz-jgk	ORGANIZATION	22s-222@5yv-jbz-jgk	PLACEKEY	22s-222@5yv-jbz-jgk	Ellen Peneyra	[]	Offices of Other Health Practitioners	Offices of All Other Miscellaneous Health Practitioners	621399	36.10289	-115.121807	[]	None	2019-07-01	+17027397716	US	2275 Renaissance Dr Ste D Las Vegas NV 89119-6797	VERIFIED_DELIVERY_POINT	PLACEKEY	22g-222@5yv-jbz-h89	PARENT	None	None
# */The database contains the following tables:
#
# 1. **dol**:
#    - Columns: RECORD_TYPE, DATA_SOURCE, RECORD_ID, case_id, BUSINESS_NAME_ORG, LEGAL_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE, BUSINESS_ADDR_POSTAL_CODE, naic_cd, naics_code_description, case_violtn_cnt.
#
# 2. **ppp**:
#    - Columns: RECORD_TYPE, DATA_SOURCE, RECORD_ID, Loan_Range, BUSINESS_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE, BUSINESS_ADDR_POSTAL_CODE, NAICS_Code, Business_Type, OwnedByRaceEthnicity, OwnedBy, OwnedByVeteran, NonProfit, JobsReported, DateApproved, Lender, CD.
#
# 3. **sg**:
#    - Columns: DATA_SOURCE, RECORD_ID, RECORD_TYPE, PLACEKEY, REL_ANCHOR_DOMAIN, REL_ANCHOR_KEY, LOCATION_NAME_ORG, BRANDS, TOP_CATEGORY, SUB_CATEGORY, NAICS_CODE, BUSINESS_GEO_LATITUDE, BUSINESS_GEO_LONGITUDE, CATEGORY_TAGS, CLOSED_ON, TRACKING_CLOSED_SINCE, PHONE_NUMBER, BUSINESS_ADDR_COUNTRY, BUSINESS_ADDR_FULL, MAILING_VERIFIED_STATUS, REL_POINTER_DOMAIN, REL_POINTER_KEY, REL_POINTER_ROLE, OPENED_ON, IS_INTERSECTION.
#
# If you have any specific questions about these tables or need data from them, feel free to ask!
#
# > Finished chain.
# {'input': 'what tables are present?',
#  'output': 'The database contains the following tables:\n\n1. **dol**: \n   - Columns: RECORD_TYPE, DATA_SOURCE, RECORD_ID, case_id, BUSINESS_NAME_ORG, LEGAL_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE, BUSINESS_ADDR_POSTAL_CODE, naic_cd, naics_code_description, case_violtn_cnt.\n\n2. **ppp**: \n   - Columns: RECORD_TYPE, DATA_SOURCE, RECORD_ID, Loan_Range, BUSINESS_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE, BUSINESS_ADDR_POSTAL_CODE, NAICS_Code, Business_Type, OwnedByRaceEthnicity, OwnedBy, OwnedByVeteran, NonProfit, JobsReported, DateApproved, Lender, CD.\n\n3. **sg**: \n   - Columns: DATA_SOURCE, RECORD_ID, RECORD_TYPE, PLACEKEY, REL_ANCHOR_DOMAIN, REL_ANCHOR_KEY, LOCATION_NAME_ORG, BRANDS, TOP_CATEGORY, SUB_CATEGORY, NAICS_CODE, BUSINESS_GEO_LATITUDE, BUSINESS_GEO_LONGITUDE, CATEGORY_TAGS, CLOSED_ON, TRACKING_CLOSED_SINCE, PHONE_NUMBER, BUSINESS_ADDR_COUNTRY, BUSINESS_ADDR_FULL, MAILING_VERIFIED_STATUS, REL_POINTER_DOMAIN, REL_POINTER_KEY, REL_POINTER_ROLE, OPENED_ON, IS_INTERSECTION. \n\nIf you have any specific questions about these tables or need data from them, feel free to ask!'}

# %%
sql_agent_executor.invoke('tell me about the tables in the database')
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# dol, ppp, sg
# Invoking: `sql_db_schema` with `{'table_names': 'dol'}`
#
#
#
# CREATE TABLE dol (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	case_id TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"LEGAL_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	naic_cd TEXT,
# 	naics_code_description TEXT,
# 	case_violtn_cnt TEXT
# )
#
# /*
# 3 rows from dol table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	case_id	BUSINESS_NAME_ORG	LEGAL_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	naic_cd	naics_code_description	case_violtn_cnt
# ORGANIZATION	DoL_WHISARD	53	1658108	Fabulous Freddy's (Trailwood)	Fabulous LLC	9611 Trail Wood Drive	Las Vegas	NV	89134	811192	Car Washes	0
# ORGANIZATION	DoL_WHISARD	165	1419689	Boulder Station Hotel & Casino	Boulder Station, Inc.	4111 Boulder Hwy	Las Vegas	NV	89121	721120	Casino Hotels	1
# ORGANIZATION	DoL_WHISARD	178	1424856	MSI Landscaping	MIST Systems International, Inc.	4820 Quality Court, #B	Las Vegas	NV	89103	561730	Landscaping Services	14
# */
# Invoking: `sql_db_schema` with `{'table_names': 'ppp'}`
#
#
#
# CREATE TABLE ppp (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"Loan_Range" TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	"NAICS_Code" TEXT,
# 	"Business_Type" TEXT,
# 	"OwnedByRaceEthnicity" TEXT,
# 	"OwnedBy" TEXT,
# 	"OwnedByVeteran" TEXT,
# 	"NonProfit" TEXT,
# 	"JobsReported" TEXT,
# 	"DateApproved" TEXT,
# 	"Lender" TEXT,
# 	"CD" TEXT
# )
#
# /*
# 3 rows from ppp table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	Loan_Range	BUSINESS_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	NAICS_Code	Business_Type	OwnedByRaceEthnicity	OwnedBy	OwnedByVeteran	NonProfit	JobsReported	DateApproved	Lender	CD
# ORGANIZATION	PPP_LOANS	7017	c $1-2 million	INFINITY HOSPICE CARE OF LAS VEGAS, LLC	5110 N 40TH ST STE 107	PHOENIX	AZ	85018	623110	Limited  Liability Company(LLC)	Unanswered	Male Owned	Unanswered		137	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7018	d $350,000-1 million	CLUB TATTOO LAS VEGAS LLC	1839 s. almaschool rd. ste 230	MESA	AZ	85210	812199	Limited  Liability Company(LLC)	Unanswered	Male Owned	Non-Veteran		15	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7021	d $350,000-1 million	LAS VEGAS LABOR, LLC	10265 W Camelback Rd, Ste 104	PHOENIX	AZ	85037	111421	Limited  Liability Company(LLC)	Unanswered	Unanswered	Unanswered		0	04/07/2020	UMB Bank, National Association	AZ-03
# */
# Invoking: `sql_db_schema` with `{'table_names': 'sg'}`
#
#
#
# CREATE TABLE sg (
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"RECORD_TYPE" TEXT,
# 	"PLACEKEY" TEXT,
# 	"REL_ANCHOR_DOMAIN" TEXT,
# 	"REL_ANCHOR_KEY" TEXT,
# 	"LOCATION_NAME_ORG" TEXT,
# 	"BRANDS" TEXT,
# 	"TOP_CATEGORY" TEXT,
# 	"SUB_CATEGORY" TEXT,
# 	"NAICS_CODE" TEXT,
# 	"BUSINESS_GEO_LATITUDE" TEXT,
# 	"BUSINESS_GEO_LONGITUDE" TEXT,
# 	"CATEGORY_TAGS" TEXT,
# 	"CLOSED_ON" TEXT,
# 	"TRACKING_CLOSED_SINCE" TEXT,
# 	"PHONE_NUMBER" TEXT,
# 	"BUSINESS_ADDR_COUNTRY" TEXT,
# 	"BUSINESS_ADDR_FULL" TEXT,
# 	"MAILING_VERIFIED_STATUS" TEXT,
# 	"REL_POINTER_DOMAIN" TEXT,
# 	"REL_POINTER_KEY" TEXT,
# 	"REL_POINTER_ROLE" TEXT,
# 	"OPENED_ON" TEXT,
# 	"IS_INTERSECTION" TEXT
# )
#
# /*
# 3 rows from sg table:
# DATA_SOURCE	RECORD_ID	RECORD_TYPE	PLACEKEY	REL_ANCHOR_DOMAIN	REL_ANCHOR_KEY	LOCATION_NAME_ORG	BRANDS	TOP_CATEGORY	SUB_CATEGORY	NAICS_CODE	BUSINESS_GEO_LATITUDE	BUSINESS_GEO_LONGITUDE	CATEGORY_TAGS	CLOSED_ON	TRACKING_CLOSED_SINCE	PHONE_NUMBER	BUSINESS_ADDR_COUNTRY	BUSINESS_ADDR_FULL	MAILING_VERIFIED_STATUS	REL_POINTER_DOMAIN	REL_POINTER_KEY	REL_POINTER_ROLE	OPENED_ON	IS_INTERSECTION
# SAFEGRAPH	225-222@5yv-j92-tn5	ORGANIZATION	225-222@5yv-j92-tn5	PLACEKEY	225-222@5yv-j92-tn5	Cantwell Michelle L Atty	[]	Legal Services	Offices of Lawyers	541110	36.145647	-115.186399	[]	2024-02-01	2019-07-01	+17023627800	US	3320 W Sahara Ave Las Vegas NV 89102-3223	VERIFIED_PREMISE	None	None	None	None	None
# SAFEGRAPH	226-222@5yv-hmm-whq	ORGANIZATION	226-222@5yv-hmm-whq	PLACEKEY	226-222@5yv-hmm-whq	Pieology Pizzeria	[ { "safegraph_brand_id": "SG_BRAND_f372f9969f6e1ae119a13ff4fc78fd2d", "safegraph_brand_name": "Pieo	Restaurants and Other Eating Places	Limited-Service Restaurants	722513	36.144906	-115.332644	[ "Counter Service", "Dinner", "Fast Food", "Lunch", "Pizza" ]	None	2019-07-01	+17023314454	US	10965 Lavender Hill Dr Ste 130 Las Vegas NV 89135-2951	VERIFIED_DELIVERY_POINT	PLACEKEY	zzw-223@5yv-hkm-rc5	PARENT	None	None
# SAFEGRAPH	22s-222@5yv-jbz-jgk	ORGANIZATION	22s-222@5yv-jbz-jgk	PLACEKEY	22s-222@5yv-jbz-jgk	Ellen Peneyra	[]	Offices of Other Health Practitioners	Offices of All Other Miscellaneous Health Practitioners	621399	36.10289	-115.121807	[]	None	2019-07-01	+17027397716	US	2275 Renaissance Dr Ste D Las Vegas NV 89119-6797	VERIFIED_DELIVERY_POINT	PLACEKEY	22g-222@5yv-jbz-h89	PARENT	None	None
# */The database contains three tables: **dol**, **ppp**, and **sg**. Here are the details for each table:
#
# ### 1. Table: dol
# - **Columns**:
#   - RECORD_TYPE
#   - DATA_SOURCE
#   - RECORD_ID
#   - case_id
#   - BUSINESS_NAME_ORG
#   - LEGAL_NAME_ORG
#   - BUSINESS_ADDR_LINE1
#   - BUSINESS_ADDR_CITY
#   - BUSINESS_ADDR_STATE
#   - BUSINESS_ADDR_POSTAL_CODE
#   - naic_cd
#   - naics_code_description
#   - case_violtn_cnt
#
# - **Sample Rows**:
#   - Fabulous Freddy's (Trailwood), Fabulous LLC, 9611 Trail Wood Drive, Las Vegas, NV, 89134, Car Washes, 0 violations.
#   - Boulder Station Hotel & Casino, Boulder Station, Inc., 4111 Boulder Hwy, Las Vegas, NV, 89121, Casino Hotels, 1 violation.
#   - MSI Landscaping, MIST Systems International, Inc., 4820 Quality Court, #B, Las Vegas, NV, 89103, Landscaping Services, 14 violations.
#
# ### 2. Table: ppp
# - **Columns**:
#   - RECORD_TYPE
#   - DATA_SOURCE
#   - RECORD_ID
#   - Loan_Range
#   - BUSINESS_NAME_ORG
#   - BUSINESS_ADDR_LINE1
#   - BUSINESS_ADDR_CITY
#   - BUSINESS_ADDR_STATE
#   - BUSINESS_ADDR_POSTAL_CODE
#   - NAICS_Code
#   - Business_Type
#   - OwnedByRaceEthnicity
#   - OwnedBy
#   - OwnedByVeteran
#   - NonProfit
#   - JobsReported
#   - DateApproved
#   - Lender
#   - CD
#
# - **Sample Rows**:
#   - INFINITY HOSPICE CARE OF LAS VEGAS, LLC, 5110 N 40TH ST STE 107, PHOENIX, AZ, $1-2 million loan range, 137 jobs reported, approved on 05/01/2020.
#   - CLUB TATTOO LAS VEGAS LLC, 1839 s. almaschool rd. ste 230, MESA, AZ, $350,000-1 million loan range, 15 jobs reported, approved on 05/01/2020.
#   - LAS VEGAS LABOR, LLC, 10265 W Camelback Rd, Ste 104, PHOENIX, AZ, $350,000-1 million loan range, 0 jobs reported, approved on 04/07/2020.
#
# ### 3. Table: sg
# - **Columns**:
#   - DATA_SOURCE
#   - RECORD_ID
#   - RECORD_TYPE
#   - PLACEKEY
#   - REL_ANCHOR_DOMAIN
#   - REL_ANCHOR_KEY
#   - LOCATION_NAME_ORG
#   - BRANDS
#   - TOP_CATEGORY
#   - SUB_CATEGORY
#   - NAICS_CODE
#   - BUSINESS_GEO_LATITUDE
#   - BUSINESS_GEO_LONGITUDE
#   - CATEGORY_TAGS
#   - CLOSED_ON
#   - TRACKING_CLOSED_SINCE
#   - PHONE_NUMBER
#   - BUSINESS_ADDR_COUNTRY
#   - BUSINESS_ADDR_FULL
#   - MAILING_VERIFIED_STATUS
#   - REL_POINTER_DOMAIN
#   - REL_POINTER_KEY
#   - REL_POINTER_ROLE
#   - OPENED_ON
#   - IS_INTERSECTION
#
# - **Sample Rows**:
#   - Cantwell Michelle L Atty, 3320 W Sahara Ave Las Vegas NV 89102-3223, Legal Services, verified premise.
#   - Pieology Pizzeria, 10965 Lavender Hill Dr Ste 130 Las Vegas NV 89135-2951, Limited-Service Restaurants, verified delivery point.
#   - Ellen Peneyra, 2275 Renaissance Dr Ste D Las Vegas NV 89119-6797, Offices of Other Health Practitioners, verified delivery point.
#
# If you have any specific questions about these tables or need further information, feel free to ask!
#
# > Finished chain.
# {'input': 'tell me about the tables in the database',
#  'output': "The database contains three tables: **dol**, **ppp**, and **sg**. Here are the details for each table:\n\n### 1. Table: dol\n- **Columns**:\n  - RECORD_TYPE\n  - DATA_SOURCE\n  - RECORD_ID\n  - case_id\n  - BUSINESS_NAME_ORG\n  - LEGAL_NAME_ORG\n  - BUSINESS_ADDR_LINE1\n  - BUSINESS_ADDR_CITY\n  - BUSINESS_ADDR_STATE\n  - BUSINESS_ADDR_POSTAL_CODE\n  - naic_cd\n  - naics_code_description\n  - case_violtn_cnt\n\n- **Sample Rows**:\n  - Fabulous Freddy's (Trailwood), Fabulous LLC, 9611 Trail Wood Drive, Las Vegas, NV, 89134, Car Washes, 0 violations.\n  - Boulder Station Hotel & Casino, Boulder Station, Inc., 4111 Boulder Hwy, Las Vegas, NV, 89121, Casino Hotels, 1 violation.\n  - MSI Landscaping, MIST Systems International, Inc., 4820 Quality Court, #B, Las Vegas, NV, 89103, Landscaping Services, 14 violations.\n\n### 2. Table: ppp\n- **Columns**:\n  - RECORD_TYPE\n  - DATA_SOURCE\n  - RECORD_ID\n  - Loan_Range\n  - BUSINESS_NAME_ORG\n  - BUSINESS_ADDR_LINE1\n  - BUSINESS_ADDR_CITY\n  - BUSINESS_ADDR_STATE\n  - BUSINESS_ADDR_POSTAL_CODE\n  - NAICS_Code\n  - Business_Type\n  - OwnedByRaceEthnicity\n  - OwnedBy\n  - OwnedByVeteran\n  - NonProfit\n  - JobsReported\n  - DateApproved\n  - Lender\n  - CD\n\n- **Sample Rows**:\n  - INFINITY HOSPICE CARE OF LAS VEGAS, LLC, 5110 N 40TH ST STE 107, PHOENIX, AZ, $1-2 million loan range, 137 jobs reported, approved on 05/01/2020.\n  - CLUB TATTOO LAS VEGAS LLC, 1839 s. almaschool rd. ste 230, MESA, AZ, $350,000-1 million loan range, 15 jobs reported, approved on 05/01/2020.\n  - LAS VEGAS LABOR, LLC, 10265 W Camelback Rd, Ste 104, PHOENIX, AZ, $350,000-1 million loan range, 0 jobs reported, approved on 04/07/2020.\n\n### 3. Table: sg\n- **Columns**:\n  - DATA_SOURCE\n  - RECORD_ID\n  - RECORD_TYPE\n  - PLACEKEY\n  - REL_ANCHOR_DOMAIN\n  - REL_ANCHOR_KEY\n  - LOCATION_NAME_ORG\n  - BRANDS\n  - TOP_CATEGORY\n  - SUB_CATEGORY\n  - NAICS_CODE\n  - BUSINESS_GEO_LATITUDE\n  - BUSINESS_GEO_LONGITUDE\n  - CATEGORY_TAGS\n  - CLOSED_ON\n  - TRACKING_CLOSED_SINCE\n  - PHONE_NUMBER\n  - BUSINESS_ADDR_COUNTRY\n  - BUSINESS_ADDR_FULL\n  - MAILING_VERIFIED_STATUS\n  - REL_POINTER_DOMAIN\n  - REL_POINTER_KEY\n  - REL_POINTER_ROLE\n  - OPENED_ON\n  - IS_INTERSECTION\n\n- **Sample Rows**:\n  - Cantwell Michelle L Atty, 3320 W Sahara Ave Las Vegas NV 89102-3223, Legal Services, verified premise.\n  - Pieology Pizzeria, 10965 Lavender Hill Dr Ste 130 Las Vegas NV 89135-2951, Limited-Service Restaurants, verified delivery point.\n  - Ellen Peneyra, 2275 Renaissance Dr Ste D Las Vegas NV 89119-6797, Offices of Other Health Practitioners, verified delivery point.\n\nIf you have any specific questions about these tables or need further information, feel free to ask!"}

# %% [markdown]
# ## Now let's ask some questions that start looking at the data itself...

# %%
sql_agent_executor.invoke('find all references to Union Cabs in all of the tables')
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# dol, ppp, sg
# Invoking: `sql_db_schema` with `{'table_names': 'dol'}`
#
#
#
# CREATE TABLE dol (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	case_id TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"LEGAL_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	naic_cd TEXT,
# 	naics_code_description TEXT,
# 	case_violtn_cnt TEXT
# )
#
# /*
# 3 rows from dol table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	case_id	BUSINESS_NAME_ORG	LEGAL_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	naic_cd	naics_code_description	case_violtn_cnt
# ORGANIZATION	DoL_WHISARD	53	1658108	Fabulous Freddy's (Trailwood)	Fabulous LLC	9611 Trail Wood Drive	Las Vegas	NV	89134	811192	Car Washes	0
# ORGANIZATION	DoL_WHISARD	165	1419689	Boulder Station Hotel & Casino	Boulder Station, Inc.	4111 Boulder Hwy	Las Vegas	NV	89121	721120	Casino Hotels	1
# ORGANIZATION	DoL_WHISARD	178	1424856	MSI Landscaping	MIST Systems International, Inc.	4820 Quality Court, #B	Las Vegas	NV	89103	561730	Landscaping Services	14
# */
# Invoking: `sql_db_schema` with `{'table_names': 'ppp'}`
#
#
#
# CREATE TABLE ppp (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"Loan_Range" TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	"NAICS_Code" TEXT,
# 	"Business_Type" TEXT,
# 	"OwnedByRaceEthnicity" TEXT,
# 	"OwnedBy" TEXT,
# 	"OwnedByVeteran" TEXT,
# 	"NonProfit" TEXT,
# 	"JobsReported" TEXT,
# 	"DateApproved" TEXT,
# 	"Lender" TEXT,
# 	"CD" TEXT
# )
#
# /*
# 3 rows from ppp table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	Loan_Range	BUSINESS_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	NAICS_Code	Business_Type	OwnedByRaceEthnicity	OwnedBy	OwnedByVeteran	NonProfit	JobsReported	DateApproved	Lender	CD
# ORGANIZATION	PPP_LOANS	7017	c $1-2 million	INFINITY HOSPICE CARE OF LAS VEGAS, LLC	5110 N 40TH ST STE 107	PHOENIX	AZ	85018	623110	Limited  Liability Company(LLC)	Unanswered	Male Owned	Unanswered		137	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7018	d $350,000-1 million	CLUB TATTOO LAS VEGAS LLC	1839 s. almaschool rd. ste 230	MESA	AZ	85210	812199	Limited  Liability Company(LLC)	Unanswered	Male Owned	Non-Veteran		15	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7021	d $350,000-1 million	LAS VEGAS LABOR, LLC	10265 W Camelback Rd, Ste 104	PHOENIX	AZ	85037	111421	Limited  Liability Company(LLC)	Unanswered	Unanswered	Unanswered		0	04/07/2020	UMB Bank, National Association	AZ-03
# */
# Invoking: `sql_db_schema` with `{'table_names': 'sg'}`
#
#
#
# CREATE TABLE sg (
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"RECORD_TYPE" TEXT,
# 	"PLACEKEY" TEXT,
# 	"REL_ANCHOR_DOMAIN" TEXT,
# 	"REL_ANCHOR_KEY" TEXT,
# 	"LOCATION_NAME_ORG" TEXT,
# 	"BRANDS" TEXT,
# 	"TOP_CATEGORY" TEXT,
# 	"SUB_CATEGORY" TEXT,
# 	"NAICS_CODE" TEXT,
# 	"BUSINESS_GEO_LATITUDE" TEXT,
# 	"BUSINESS_GEO_LONGITUDE" TEXT,
# 	"CATEGORY_TAGS" TEXT,
# 	"CLOSED_ON" TEXT,
# 	"TRACKING_CLOSED_SINCE" TEXT,
# 	"PHONE_NUMBER" TEXT,
# 	"BUSINESS_ADDR_COUNTRY" TEXT,
# 	"BUSINESS_ADDR_FULL" TEXT,
# 	"MAILING_VERIFIED_STATUS" TEXT,
# 	"REL_POINTER_DOMAIN" TEXT,
# 	"REL_POINTER_KEY" TEXT,
# 	"REL_POINTER_ROLE" TEXT,
# 	"OPENED_ON" TEXT,
# 	"IS_INTERSECTION" TEXT
# )
#
# /*
# 3 rows from sg table:
# DATA_SOURCE	RECORD_ID	RECORD_TYPE	PLACEKEY	REL_ANCHOR_DOMAIN	REL_ANCHOR_KEY	LOCATION_NAME_ORG	BRANDS	TOP_CATEGORY	SUB_CATEGORY	NAICS_CODE	BUSINESS_GEO_LATITUDE	BUSINESS_GEO_LONGITUDE	CATEGORY_TAGS	CLOSED_ON	TRACKING_CLOSED_SINCE	PHONE_NUMBER	BUSINESS_ADDR_COUNTRY	BUSINESS_ADDR_FULL	MAILING_VERIFIED_STATUS	REL_POINTER_DOMAIN	REL_POINTER_KEY	REL_POINTER_ROLE	OPENED_ON	IS_INTERSECTION
# SAFEGRAPH	225-222@5yv-j92-tn5	ORGANIZATION	225-222@5yv-j92-tn5	PLACEKEY	225-222@5yv-j92-tn5	Cantwell Michelle L Atty	[]	Legal Services	Offices of Lawyers	541110	36.145647	-115.186399	[]	2024-02-01	2019-07-01	+17023627800	US	3320 W Sahara Ave Las Vegas NV 89102-3223	VERIFIED_PREMISE	None	None	None	None	None
# SAFEGRAPH	226-222@5yv-hmm-whq	ORGANIZATION	226-222@5yv-hmm-whq	PLACEKEY	226-222@5yv-hmm-whq	Pieology Pizzeria	[ { "safegraph_brand_id": "SG_BRAND_f372f9969f6e1ae119a13ff4fc78fd2d", "safegraph_brand_name": "Pieo	Restaurants and Other Eating Places	Limited-Service Restaurants	722513	36.144906	-115.332644	[ "Counter Service", "Dinner", "Fast Food", "Lunch", "Pizza" ]	None	2019-07-01	+17023314454	US	10965 Lavender Hill Dr Ste 130 Las Vegas NV 89135-2951	VERIFIED_DELIVERY_POINT	PLACEKEY	zzw-223@5yv-hkm-rc5	PARENT	None	None
# SAFEGRAPH	22s-222@5yv-jbz-jgk	ORGANIZATION	22s-222@5yv-jbz-jgk	PLACEKEY	22s-222@5yv-jbz-jgk	Ellen Peneyra	[]	Offices of Other Health Practitioners	Offices of All Other Miscellaneous Health Practitioners	621399	36.10289	-115.121807	[]	None	2019-07-01	+17027397716	US	2275 Renaissance Dr Ste D Las Vegas NV 89119-6797	VERIFIED_DELIVERY_POINT	PLACEKEY	22g-222@5yv-jbz-h89	PARENT	None	None
# */
# Invoking: `sql_db_query_checker` with `{'query': "SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG FROM dol WHERE BUSINESS_NAME_ORG LIKE '%Union Cabs%' OR LEGAL_NAME_ORG LIKE '%Union Cabs%' LIMIT 10;"}`
# responded: The database contains three tables: `dol`, `ppp`, and `sg`. The relevant columns for searching references to "Union Cabs" in these tables are:
#
# - **dol**: `BUSINESS_NAME_ORG`, `LEGAL_NAME_ORG`
# - **ppp**: `BUSINESS_NAME_ORG`
# - **sg**: `LOCATION_NAME_ORG`, `BRANDS`
#
# I will now create queries to search for "Union Cabs" in these relevant columns across the three tables. Each query will be limited to 10 results.
#
# Here are the queries I will run:
#
# 1. For the `dol` table:
#    ```sql
#    SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG FROM dol WHERE BUSINESS_NAME_ORG LIKE '%Union Cabs%' OR LEGAL_NAME_ORG LIKE '%Union Cabs%' LIMIT 10;
#    ```
#
# 2. For the `ppp` table:
#    ```sql
#    SELECT BUSINESS_NAME_ORG FROM ppp WHERE BUSINESS_NAME_ORG LIKE '%Union Cabs%' LIMIT 10;
#    ```
#
# 3. For the `sg` table:
#    ```sql
#    SELECT LOCATION_NAME_ORG, BRANDS FROM sg WHERE LOCATION_NAME_ORG LIKE '%Union Cabs%' OR BRANDS LIKE '%Union Cabs%' LIMIT 10;
#    ```
#
# I will check these queries for correctness before executing them.
#
# ```sql
# SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG FROM dol WHERE BUSINESS_NAME_ORG LIKE '%Union Cabs%' OR LEGAL_NAME_ORG LIKE '%Union Cabs%' LIMIT 10;
# ```
# Invoking: `sql_db_query_checker` with `{'query': "SELECT BUSINESS_NAME_ORG FROM ppp WHERE BUSINESS_NAME_ORG LIKE '%Union Cabs%' LIMIT 10;"}`
# responded: The database contains three tables: `dol`, `ppp`, and `sg`. The relevant columns for searching references to "Union Cabs" in these tables are:
#
# - **dol**: `BUSINESS_NAME_ORG`, `LEGAL_NAME_ORG`
# - **ppp**: `BUSINESS_NAME_ORG`
# - **sg**: `LOCATION_NAME_ORG`, `BRANDS`
#
# I will now create queries to search for "Union Cabs" in these relevant columns across the three tables. Each query will be limited to 10 results.
#
# Here are the queries I will run:
#
# 1. For the `dol` table:
#    ```sql
#    SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG FROM dol WHERE BUSINESS_NAME_ORG LIKE '%Union Cabs%' OR LEGAL_NAME_ORG LIKE '%Union Cabs%' LIMIT 10;
#    ```
#
# 2. For the `ppp` table:
#    ```sql
#    SELECT BUSINESS_NAME_ORG FROM ppp WHERE BUSINESS_NAME_ORG LIKE '%Union Cabs%' LIMIT 10;
#    ```
#
# 3. For the `sg` table:
#    ```sql
#    SELECT LOCATION_NAME_ORG, BRANDS FROM sg WHERE LOCATION_NAME_ORG LIKE '%Union Cabs%' OR BRANDS LIKE '%Union Cabs%' LIMIT 10;
#    ```
#
# I will check these queries for correctness before executing them.
#
# ```sql
# SELECT BUSINESS_NAME_ORG FROM ppp WHERE BUSINESS_NAME_ORG LIKE '%Union Cabs%' LIMIT 10;
# ```
# Invoking: `sql_db_query_checker` with `{'query': "SELECT LOCATION_NAME_ORG, BRANDS FROM sg WHERE LOCATION_NAME_ORG LIKE '%Union Cabs%' OR BRANDS LIKE '%Union Cabs%' LIMIT 10;"}`
# responded: The database contains three tables: `dol`, `ppp`, and `sg`. The relevant columns for searching references to "Union Cabs" in these tables are:
#
# - **dol**: `BUSINESS_NAME_ORG`, `LEGAL_NAME_ORG`
# - **ppp**: `BUSINESS_NAME_ORG`
# - **sg**: `LOCATION_NAME_ORG`, `BRANDS`
#
# I will now create queries to search for "Union Cabs" in these relevant columns across the three tables. Each query will be limited to 10 results.
#
# Here are the queries I will run:
#
# 1. For the `dol` table:
#    ```sql
#    SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG FROM dol WHERE BUSINESS_NAME_ORG LIKE '%Union Cabs%' OR LEGAL_NAME_ORG LIKE '%Union Cabs%' LIMIT 10;
#    ```
#
# 2. For the `ppp` table:
#    ```sql
#    SELECT BUSINESS_NAME_ORG FROM ppp WHERE BUSINESS_NAME_ORG LIKE '%Union Cabs%' LIMIT 10;
#    ```
#
# 3. For the `sg` table:
#    ```sql
#    SELECT LOCATION_NAME_ORG, BRANDS FROM sg WHERE LOCATION_NAME_ORG LIKE '%Union Cabs%' OR BRANDS LIKE '%Union Cabs%' LIMIT 10;
#    ```
#
# I will check these queries for correctness before executing them.
#
# ```sql
# SELECT LOCATION_NAME_ORG, BRANDS FROM sg WHERE LOCATION_NAME_ORG LIKE '%Union Cabs%' OR BRANDS LIKE '%Union Cabs%' LIMIT 10;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG FROM dol WHERE BUSINESS_NAME_ORG LIKE '%Union Cabs%' OR LEGAL_NAME_ORG LIKE '%Union Cabs%' LIMIT 10;"}`
#
#
#
# Invoking: `sql_db_query` with `{'query': "SELECT BUSINESS_NAME_ORG FROM ppp WHERE BUSINESS_NAME_ORG LIKE '%Union Cabs%' LIMIT 10;"}`
#
#
#
# Invoking: `sql_db_query` with `{'query': "SELECT LOCATION_NAME_ORG, BRANDS FROM sg WHERE LOCATION_NAME_ORG LIKE '%Union Cabs%' OR BRANDS LIKE '%Union Cabs%' LIMIT 10;"}`
#
#
# [('Union Cabs', '[]')]The search for references to "Union Cabs" yielded the following results:
#
# 1. **From the `dol` table**: No results were found.
# 2. **From the `ppp` table**: No results were found.
# 3. **From the `sg` table**: One result was found:
#    - **Location Name**: Union Cabs
#    - **Brands**: []
#
# In summary, "Union Cabs" was found only in the `sg` table.
#
# > Finished chain.
# {'input': 'find all references to Union Cabs in all of the tables',
#  'output': 'The search for references to "Union Cabs" yielded the following results:\n\n1. **From the `dol` table**: No results were found.\n2. **From the `ppp` table**: No results were found.\n3. **From the `sg` table**: One result was found:\n   - **Location Name**: Union Cabs\n   - **Brands**: []\n\nIn summary, "Union Cabs" was found only in the `sg` table.'}

# %%
sql_agent_executor.invoke('does Union Cabs have any violations?')
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# dol, ppp, sg
# Invoking: `sql_db_schema` with `{'table_names': 'dol'}`
#
#
#
# CREATE TABLE dol (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	case_id TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"LEGAL_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	naic_cd TEXT,
# 	naics_code_description TEXT,
# 	case_violtn_cnt TEXT
# )
#
# /*
# 3 rows from dol table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	case_id	BUSINESS_NAME_ORG	LEGAL_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	naic_cd	naics_code_description	case_violtn_cnt
# ORGANIZATION	DoL_WHISARD	53	1658108	Fabulous Freddy's (Trailwood)	Fabulous LLC	9611 Trail Wood Drive	Las Vegas	NV	89134	811192	Car Washes	0
# ORGANIZATION	DoL_WHISARD	165	1419689	Boulder Station Hotel & Casino	Boulder Station, Inc.	4111 Boulder Hwy	Las Vegas	NV	89121	721120	Casino Hotels	1
# ORGANIZATION	DoL_WHISARD	178	1424856	MSI Landscaping	MIST Systems International, Inc.	4820 Quality Court, #B	Las Vegas	NV	89103	561730	Landscaping Services	14
# */
# Invoking: `sql_db_schema` with `{'table_names': 'ppp'}`
#
#
#
# CREATE TABLE ppp (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"Loan_Range" TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	"NAICS_Code" TEXT,
# 	"Business_Type" TEXT,
# 	"OwnedByRaceEthnicity" TEXT,
# 	"OwnedBy" TEXT,
# 	"OwnedByVeteran" TEXT,
# 	"NonProfit" TEXT,
# 	"JobsReported" TEXT,
# 	"DateApproved" TEXT,
# 	"Lender" TEXT,
# 	"CD" TEXT
# )
#
# /*
# 3 rows from ppp table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	Loan_Range	BUSINESS_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	NAICS_Code	Business_Type	OwnedByRaceEthnicity	OwnedBy	OwnedByVeteran	NonProfit	JobsReported	DateApproved	Lender	CD
# ORGANIZATION	PPP_LOANS	7017	c $1-2 million	INFINITY HOSPICE CARE OF LAS VEGAS, LLC	5110 N 40TH ST STE 107	PHOENIX	AZ	85018	623110	Limited  Liability Company(LLC)	Unanswered	Male Owned	Unanswered		137	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7018	d $350,000-1 million	CLUB TATTOO LAS VEGAS LLC	1839 s. almaschool rd. ste 230	MESA	AZ	85210	812199	Limited  Liability Company(LLC)	Unanswered	Male Owned	Non-Veteran		15	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7021	d $350,000-1 million	LAS VEGAS LABOR, LLC	10265 W Camelback Rd, Ste 104	PHOENIX	AZ	85037	111421	Limited  Liability Company(LLC)	Unanswered	Unanswered	Unanswered		0	04/07/2020	UMB Bank, National Association	AZ-03
# */
# Invoking: `sql_db_schema` with `{'table_names': 'sg'}`
#
#
#
# CREATE TABLE sg (
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"RECORD_TYPE" TEXT,
# 	"PLACEKEY" TEXT,
# 	"REL_ANCHOR_DOMAIN" TEXT,
# 	"REL_ANCHOR_KEY" TEXT,
# 	"LOCATION_NAME_ORG" TEXT,
# 	"BRANDS" TEXT,
# 	"TOP_CATEGORY" TEXT,
# 	"SUB_CATEGORY" TEXT,
# 	"NAICS_CODE" TEXT,
# 	"BUSINESS_GEO_LATITUDE" TEXT,
# 	"BUSINESS_GEO_LONGITUDE" TEXT,
# 	"CATEGORY_TAGS" TEXT,
# 	"CLOSED_ON" TEXT,
# 	"TRACKING_CLOSED_SINCE" TEXT,
# 	"PHONE_NUMBER" TEXT,
# 	"BUSINESS_ADDR_COUNTRY" TEXT,
# 	"BUSINESS_ADDR_FULL" TEXT,
# 	"MAILING_VERIFIED_STATUS" TEXT,
# 	"REL_POINTER_DOMAIN" TEXT,
# 	"REL_POINTER_KEY" TEXT,
# 	"REL_POINTER_ROLE" TEXT,
# 	"OPENED_ON" TEXT,
# 	"IS_INTERSECTION" TEXT
# )
#
# /*
# 3 rows from sg table:
# DATA_SOURCE	RECORD_ID	RECORD_TYPE	PLACEKEY	REL_ANCHOR_DOMAIN	REL_ANCHOR_KEY	LOCATION_NAME_ORG	BRANDS	TOP_CATEGORY	SUB_CATEGORY	NAICS_CODE	BUSINESS_GEO_LATITUDE	BUSINESS_GEO_LONGITUDE	CATEGORY_TAGS	CLOSED_ON	TRACKING_CLOSED_SINCE	PHONE_NUMBER	BUSINESS_ADDR_COUNTRY	BUSINESS_ADDR_FULL	MAILING_VERIFIED_STATUS	REL_POINTER_DOMAIN	REL_POINTER_KEY	REL_POINTER_ROLE	OPENED_ON	IS_INTERSECTION
# SAFEGRAPH	225-222@5yv-j92-tn5	ORGANIZATION	225-222@5yv-j92-tn5	PLACEKEY	225-222@5yv-j92-tn5	Cantwell Michelle L Atty	[]	Legal Services	Offices of Lawyers	541110	36.145647	-115.186399	[]	2024-02-01	2019-07-01	+17023627800	US	3320 W Sahara Ave Las Vegas NV 89102-3223	VERIFIED_PREMISE	None	None	None	None	None
# SAFEGRAPH	226-222@5yv-hmm-whq	ORGANIZATION	226-222@5yv-hmm-whq	PLACEKEY	226-222@5yv-hmm-whq	Pieology Pizzeria	[ { "safegraph_brand_id": "SG_BRAND_f372f9969f6e1ae119a13ff4fc78fd2d", "safegraph_brand_name": "Pieo	Restaurants and Other Eating Places	Limited-Service Restaurants	722513	36.144906	-115.332644	[ "Counter Service", "Dinner", "Fast Food", "Lunch", "Pizza" ]	None	2019-07-01	+17023314454	US	10965 Lavender Hill Dr Ste 130 Las Vegas NV 89135-2951	VERIFIED_DELIVERY_POINT	PLACEKEY	zzw-223@5yv-hkm-rc5	PARENT	None	None
# SAFEGRAPH	22s-222@5yv-jbz-jgk	ORGANIZATION	22s-222@5yv-jbz-jgk	PLACEKEY	22s-222@5yv-jbz-jgk	Ellen Peneyra	[]	Offices of Other Health Practitioners	Offices of All Other Miscellaneous Health Practitioners	621399	36.10289	-115.121807	[]	None	2019-07-01	+17027397716	US	2275 Renaissance Dr Ste D Las Vegas NV 89119-6797	VERIFIED_DELIVERY_POINT	PLACEKEY	22g-222@5yv-jbz-h89	PARENT	None	None
# */
# Invoking: `sql_db_query_checker` with `{'query': "SELECT BUSINESS_NAME_ORG, case_violtn_cnt \nFROM dol \nWHERE BUSINESS_NAME_ORG = 'Union Cabs';"}`
# responded: The relevant table for violations appears to be the `dol` table, which includes a column for `case_violtn_cnt`. I will query this table to check if "Union Cabs" has any violations.
#
# The query will look for records where the `BUSINESS_NAME_ORG` is "Union Cabs" and will return the count of violations.
#
# Here is the query I will use:
# ```sql
# SELECT BUSINESS_NAME_ORG, case_violtn_cnt
# FROM dol
# WHERE BUSINESS_NAME_ORG = 'Union Cabs';
# ```
#
# I will check this query for correctness before executing it.
#
# ```sql
# SELECT BUSINESS_NAME_ORG, case_violtn_cnt
# FROM dol
# WHERE BUSINESS_NAME_ORG = 'Union Cabs';
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT BUSINESS_NAME_ORG, case_violtn_cnt \nFROM dol \nWHERE BUSINESS_NAME_ORG = 'Union Cabs';"}`
#
#
# It appears that there are no records for "Union Cabs" in the database, which means there are no violations associated with that business.
#
# > Finished chain.
# {'input': 'does Union Cabs have any violations?',
#  'output': 'It appears that there are no records for "Union Cabs" in the database, which means there are no violations associated with that business.'}

# %% [markdown]
# ## Uh oh!
#
# Houston, we have a problem!
#
# According to these basic SQL queries, Union Cabs (an entry in the SafeGraph data) doesn't have any violations.  But if we look at the DOL data there is an entry called "Union Cab" (singular) that actually DOES have violations.   Futher, if you go into `G2Explorer.py` you will see that there are several other related cab companies with the same address like LV Cabs and Vegas Western Cabs who have additional violations.  So if you were wanting to get an accurate accounting of those violations (or many other questions you could think of to ask this data), you will miss it because you have not resolved the relationships between each of these (seemingly unrelated) cab companies!
#
# ### Now let's ask something a little more complicated...

# %%
sql_agent_executor.invoke('of the companies that took on the biggest loans, which had the most violations?')
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# dol, ppp, sg
# Invoking: `sql_db_schema` with `{'table_names': 'dol'}`
#
#
#
# CREATE TABLE dol (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	case_id TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"LEGAL_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	naic_cd TEXT,
# 	naics_code_description TEXT,
# 	case_violtn_cnt TEXT
# )
#
# /*
# 3 rows from dol table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	case_id	BUSINESS_NAME_ORG	LEGAL_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	naic_cd	naics_code_description	case_violtn_cnt
# ORGANIZATION	DoL_WHISARD	53	1658108	Fabulous Freddy's (Trailwood)	Fabulous LLC	9611 Trail Wood Drive	Las Vegas	NV	89134	811192	Car Washes	0
# ORGANIZATION	DoL_WHISARD	165	1419689	Boulder Station Hotel & Casino	Boulder Station, Inc.	4111 Boulder Hwy	Las Vegas	NV	89121	721120	Casino Hotels	1
# ORGANIZATION	DoL_WHISARD	178	1424856	MSI Landscaping	MIST Systems International, Inc.	4820 Quality Court, #B	Las Vegas	NV	89103	561730	Landscaping Services	14
# */
# Invoking: `sql_db_schema` with `{'table_names': 'ppp'}`
#
#
#
# CREATE TABLE ppp (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"Loan_Range" TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	"NAICS_Code" TEXT,
# 	"Business_Type" TEXT,
# 	"OwnedByRaceEthnicity" TEXT,
# 	"OwnedBy" TEXT,
# 	"OwnedByVeteran" TEXT,
# 	"NonProfit" TEXT,
# 	"JobsReported" TEXT,
# 	"DateApproved" TEXT,
# 	"Lender" TEXT,
# 	"CD" TEXT
# )
#
# /*
# 3 rows from ppp table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	Loan_Range	BUSINESS_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	NAICS_Code	Business_Type	OwnedByRaceEthnicity	OwnedBy	OwnedByVeteran	NonProfit	JobsReported	DateApproved	Lender	CD
# ORGANIZATION	PPP_LOANS	7017	c $1-2 million	INFINITY HOSPICE CARE OF LAS VEGAS, LLC	5110 N 40TH ST STE 107	PHOENIX	AZ	85018	623110	Limited  Liability Company(LLC)	Unanswered	Male Owned	Unanswered		137	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7018	d $350,000-1 million	CLUB TATTOO LAS VEGAS LLC	1839 s. almaschool rd. ste 230	MESA	AZ	85210	812199	Limited  Liability Company(LLC)	Unanswered	Male Owned	Non-Veteran		15	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7021	d $350,000-1 million	LAS VEGAS LABOR, LLC	10265 W Camelback Rd, Ste 104	PHOENIX	AZ	85037	111421	Limited  Liability Company(LLC)	Unanswered	Unanswered	Unanswered		0	04/07/2020	UMB Bank, National Association	AZ-03
# */
# Invoking: `sql_db_schema` with `{'table_names': 'sg'}`
#
#
#
# CREATE TABLE sg (
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"RECORD_TYPE" TEXT,
# 	"PLACEKEY" TEXT,
# 	"REL_ANCHOR_DOMAIN" TEXT,
# 	"REL_ANCHOR_KEY" TEXT,
# 	"LOCATION_NAME_ORG" TEXT,
# 	"BRANDS" TEXT,
# 	"TOP_CATEGORY" TEXT,
# 	"SUB_CATEGORY" TEXT,
# 	"NAICS_CODE" TEXT,
# 	"BUSINESS_GEO_LATITUDE" TEXT,
# 	"BUSINESS_GEO_LONGITUDE" TEXT,
# 	"CATEGORY_TAGS" TEXT,
# 	"CLOSED_ON" TEXT,
# 	"TRACKING_CLOSED_SINCE" TEXT,
# 	"PHONE_NUMBER" TEXT,
# 	"BUSINESS_ADDR_COUNTRY" TEXT,
# 	"BUSINESS_ADDR_FULL" TEXT,
# 	"MAILING_VERIFIED_STATUS" TEXT,
# 	"REL_POINTER_DOMAIN" TEXT,
# 	"REL_POINTER_KEY" TEXT,
# 	"REL_POINTER_ROLE" TEXT,
# 	"OPENED_ON" TEXT,
# 	"IS_INTERSECTION" TEXT
# )
#
# /*
# 3 rows from sg table:
# DATA_SOURCE	RECORD_ID	RECORD_TYPE	PLACEKEY	REL_ANCHOR_DOMAIN	REL_ANCHOR_KEY	LOCATION_NAME_ORG	BRANDS	TOP_CATEGORY	SUB_CATEGORY	NAICS_CODE	BUSINESS_GEO_LATITUDE	BUSINESS_GEO_LONGITUDE	CATEGORY_TAGS	CLOSED_ON	TRACKING_CLOSED_SINCE	PHONE_NUMBER	BUSINESS_ADDR_COUNTRY	BUSINESS_ADDR_FULL	MAILING_VERIFIED_STATUS	REL_POINTER_DOMAIN	REL_POINTER_KEY	REL_POINTER_ROLE	OPENED_ON	IS_INTERSECTION
# SAFEGRAPH	225-222@5yv-j92-tn5	ORGANIZATION	225-222@5yv-j92-tn5	PLACEKEY	225-222@5yv-j92-tn5	Cantwell Michelle L Atty	[]	Legal Services	Offices of Lawyers	541110	36.145647	-115.186399	[]	2024-02-01	2019-07-01	+17023627800	US	3320 W Sahara Ave Las Vegas NV 89102-3223	VERIFIED_PREMISE	None	None	None	None	None
# SAFEGRAPH	226-222@5yv-hmm-whq	ORGANIZATION	226-222@5yv-hmm-whq	PLACEKEY	226-222@5yv-hmm-whq	Pieology Pizzeria	[ { "safegraph_brand_id": "SG_BRAND_f372f9969f6e1ae119a13ff4fc78fd2d", "safegraph_brand_name": "Pieo	Restaurants and Other Eating Places	Limited-Service Restaurants	722513	36.144906	-115.332644	[ "Counter Service", "Dinner", "Fast Food", "Lunch", "Pizza" ]	None	2019-07-01	+17023314454	US	10965 Lavender Hill Dr Ste 130 Las Vegas NV 89135-2951	VERIFIED_DELIVERY_POINT	PLACEKEY	zzw-223@5yv-hkm-rc5	PARENT	None	None
# SAFEGRAPH	22s-222@5yv-jbz-jgk	ORGANIZATION	22s-222@5yv-jbz-jgk	PLACEKEY	22s-222@5yv-jbz-jgk	Ellen Peneyra	[]	Offices of Other Health Practitioners	Offices of All Other Miscellaneous Health Practitioners	621399	36.10289	-115.121807	[]	None	2019-07-01	+17027397716	US	2275 Renaissance Dr Ste D Las Vegas NV 89119-6797	VERIFIED_DELIVERY_POINT	PLACEKEY	22g-222@5yv-jbz-h89	PARENT	None	None
# */
# Invoking: `sql_db_query_checker` with `{'query': "SELECT p.BUSINESS_NAME_ORG, p.Loan_Range, d.case_violtn_cnt\nFROM ppp p\nJOIN dol d ON p.BUSINESS_NAME_ORG = d.BUSINESS_NAME_ORG\nORDER BY CAST(SUBSTR(p.Loan_Range, INSTR(p.Loan_Range, '$') + 1, INSTR(p.Loan_Range, ' million') - INSTR(p.Loan_Range, '$') - 1) AS INTEGER) DESC\nLIMIT 10;"}`
# responded: The relevant tables for your question are:
#
# 1. **dol**: Contains information about violations, including `case_violtn_cnt` (the count of violations) and `BUSINESS_NAME_ORG` (the name of the business).
# 2. **ppp**: Contains information about loans, including `Loan_Range` and `BUSINESS_NAME_ORG`.
#
# To find the companies that took on the biggest loans and had the most violations, I will need to join these two tables on the `BUSINESS_NAME_ORG` column and then filter and order the results accordingly.
#
# I will first identify the companies with the largest loan amounts from the `ppp` table and then join that with the `dol` table to get the violation counts.
#
# Let's construct the query to find the top 10 companies with the largest loans and their corresponding violation counts. I will assume that the largest loan amounts are represented by the `Loan_Range` column, which I will need to parse to extract numerical values for sorting.
#
# I'll start by checking the query for correctness before executing it.
#
# Here’s the query I will use:
#
# ```sql
# SELECT p.BUSINESS_NAME_ORG, p.Loan_Range, d.case_violtn_cnt
# FROM ppp p
# JOIN dol d ON p.BUSINESS_NAME_ORG = d.BUSINESS_NAME_ORG
# ORDER BY CAST(SUBSTR(p.Loan_Range, INSTR(p.Loan_Range, '$') + 1, INSTR(p.Loan_Range, ' million') - INSTR(p.Loan_Range, '$') - 1) AS INTEGER) DESC
# LIMIT 10;
# ```
#
# Now, I will check this query for correctness.
#
# ```sql
# SELECT p.BUSINESS_NAME_ORG, p.Loan_Range, d.case_violtn_cnt
# FROM ppp p
# JOIN dol d ON p.BUSINESS_NAME_ORG = d.BUSINESS_NAME_ORG
# ORDER BY CAST(SUBSTR(p.Loan_Range, INSTR(p.Loan_Range, '$') + 1, INSTR(p.Loan_Range, ' million') - INSTR(p.Loan_Range, '$') - 1) AS INTEGER) DESC
# LIMIT 10;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT p.BUSINESS_NAME_ORG, p.Loan_Range, d.case_violtn_cnt\nFROM ppp p\nJOIN dol d ON p.BUSINESS_NAME_ORG = d.BUSINESS_NAME_ORG\nORDER BY CAST(SUBSTR(p.Loan_Range, INSTR(p.Loan_Range, '$') + 1, INSTR(p.Loan_Range, ' million') - INSTR(p.Loan_Range, '$') - 1) AS INTEGER) DESC\nLIMIT 10;"}`
#
#
# [('HSG, LLC', 'd $350,000-1 million', '36')]The company that took on one of the biggest loans and had the most violations is:
#
# - **Business Name**: HSG, LLC
# - **Loan Range**: $350,000 - $1 million
# - **Number of Violations**: 36
#
# If you need more information or additional examples, feel free to ask!
#
# > Finished chain.
# {'input': 'of the companies that took on the biggest loans, which had the most violations?',
#  'output': 'The company that took on one of the biggest loans and had the most violations is:\n\n- **Business Name**: HSG, LLC\n- **Loan Range**: $350,000 - $1 million\n- **Number of Violations**: 36\n\nIf you need more information or additional examples, feel free to ask!'}

# %% [markdown]
# ### Interesting.  Who are these folks?

# %%
sql_agent_executor.invoke('find all references to HSG, LLC')
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# dol, ppp, sg
# Invoking: `sql_db_schema` with `{'table_names': 'dol'}`
#
#
#
# CREATE TABLE dol (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	case_id TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"LEGAL_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	naic_cd TEXT,
# 	naics_code_description TEXT,
# 	case_violtn_cnt TEXT
# )
#
# /*
# 3 rows from dol table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	case_id	BUSINESS_NAME_ORG	LEGAL_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	naic_cd	naics_code_description	case_violtn_cnt
# ORGANIZATION	DoL_WHISARD	53	1658108	Fabulous Freddy's (Trailwood)	Fabulous LLC	9611 Trail Wood Drive	Las Vegas	NV	89134	811192	Car Washes	0
# ORGANIZATION	DoL_WHISARD	165	1419689	Boulder Station Hotel & Casino	Boulder Station, Inc.	4111 Boulder Hwy	Las Vegas	NV	89121	721120	Casino Hotels	1
# ORGANIZATION	DoL_WHISARD	178	1424856	MSI Landscaping	MIST Systems International, Inc.	4820 Quality Court, #B	Las Vegas	NV	89103	561730	Landscaping Services	14
# */
# Invoking: `sql_db_schema` with `{'table_names': 'ppp'}`
#
#
#
# CREATE TABLE ppp (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"Loan_Range" TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	"NAICS_Code" TEXT,
# 	"Business_Type" TEXT,
# 	"OwnedByRaceEthnicity" TEXT,
# 	"OwnedBy" TEXT,
# 	"OwnedByVeteran" TEXT,
# 	"NonProfit" TEXT,
# 	"JobsReported" TEXT,
# 	"DateApproved" TEXT,
# 	"Lender" TEXT,
# 	"CD" TEXT
# )
#
# /*
# 3 rows from ppp table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	Loan_Range	BUSINESS_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	NAICS_Code	Business_Type	OwnedByRaceEthnicity	OwnedBy	OwnedByVeteran	NonProfit	JobsReported	DateApproved	Lender	CD
# ORGANIZATION	PPP_LOANS	7017	c $1-2 million	INFINITY HOSPICE CARE OF LAS VEGAS, LLC	5110 N 40TH ST STE 107	PHOENIX	AZ	85018	623110	Limited  Liability Company(LLC)	Unanswered	Male Owned	Unanswered		137	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7018	d $350,000-1 million	CLUB TATTOO LAS VEGAS LLC	1839 s. almaschool rd. ste 230	MESA	AZ	85210	812199	Limited  Liability Company(LLC)	Unanswered	Male Owned	Non-Veteran		15	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7021	d $350,000-1 million	LAS VEGAS LABOR, LLC	10265 W Camelback Rd, Ste 104	PHOENIX	AZ	85037	111421	Limited  Liability Company(LLC)	Unanswered	Unanswered	Unanswered		0	04/07/2020	UMB Bank, National Association	AZ-03
# */
# Invoking: `sql_db_schema` with `{'table_names': 'sg'}`
#
#
#
# CREATE TABLE sg (
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"RECORD_TYPE" TEXT,
# 	"PLACEKEY" TEXT,
# 	"REL_ANCHOR_DOMAIN" TEXT,
# 	"REL_ANCHOR_KEY" TEXT,
# 	"LOCATION_NAME_ORG" TEXT,
# 	"BRANDS" TEXT,
# 	"TOP_CATEGORY" TEXT,
# 	"SUB_CATEGORY" TEXT,
# 	"NAICS_CODE" TEXT,
# 	"BUSINESS_GEO_LATITUDE" TEXT,
# 	"BUSINESS_GEO_LONGITUDE" TEXT,
# 	"CATEGORY_TAGS" TEXT,
# 	"CLOSED_ON" TEXT,
# 	"TRACKING_CLOSED_SINCE" TEXT,
# 	"PHONE_NUMBER" TEXT,
# 	"BUSINESS_ADDR_COUNTRY" TEXT,
# 	"BUSINESS_ADDR_FULL" TEXT,
# 	"MAILING_VERIFIED_STATUS" TEXT,
# 	"REL_POINTER_DOMAIN" TEXT,
# 	"REL_POINTER_KEY" TEXT,
# 	"REL_POINTER_ROLE" TEXT,
# 	"OPENED_ON" TEXT,
# 	"IS_INTERSECTION" TEXT
# )
#
# /*
# 3 rows from sg table:
# DATA_SOURCE	RECORD_ID	RECORD_TYPE	PLACEKEY	REL_ANCHOR_DOMAIN	REL_ANCHOR_KEY	LOCATION_NAME_ORG	BRANDS	TOP_CATEGORY	SUB_CATEGORY	NAICS_CODE	BUSINESS_GEO_LATITUDE	BUSINESS_GEO_LONGITUDE	CATEGORY_TAGS	CLOSED_ON	TRACKING_CLOSED_SINCE	PHONE_NUMBER	BUSINESS_ADDR_COUNTRY	BUSINESS_ADDR_FULL	MAILING_VERIFIED_STATUS	REL_POINTER_DOMAIN	REL_POINTER_KEY	REL_POINTER_ROLE	OPENED_ON	IS_INTERSECTION
# SAFEGRAPH	225-222@5yv-j92-tn5	ORGANIZATION	225-222@5yv-j92-tn5	PLACEKEY	225-222@5yv-j92-tn5	Cantwell Michelle L Atty	[]	Legal Services	Offices of Lawyers	541110	36.145647	-115.186399	[]	2024-02-01	2019-07-01	+17023627800	US	3320 W Sahara Ave Las Vegas NV 89102-3223	VERIFIED_PREMISE	None	None	None	None	None
# SAFEGRAPH	226-222@5yv-hmm-whq	ORGANIZATION	226-222@5yv-hmm-whq	PLACEKEY	226-222@5yv-hmm-whq	Pieology Pizzeria	[ { "safegraph_brand_id": "SG_BRAND_f372f9969f6e1ae119a13ff4fc78fd2d", "safegraph_brand_name": "Pieo	Restaurants and Other Eating Places	Limited-Service Restaurants	722513	36.144906	-115.332644	[ "Counter Service", "Dinner", "Fast Food", "Lunch", "Pizza" ]	None	2019-07-01	+17023314454	US	10965 Lavender Hill Dr Ste 130 Las Vegas NV 89135-2951	VERIFIED_DELIVERY_POINT	PLACEKEY	zzw-223@5yv-hkm-rc5	PARENT	None	None
# SAFEGRAPH	22s-222@5yv-jbz-jgk	ORGANIZATION	22s-222@5yv-jbz-jgk	PLACEKEY	22s-222@5yv-jbz-jgk	Ellen Peneyra	[]	Offices of Other Health Practitioners	Offices of All Other Miscellaneous Health Practitioners	621399	36.10289	-115.121807	[]	None	2019-07-01	+17027397716	US	2275 Renaissance Dr Ste D Las Vegas NV 89119-6797	VERIFIED_DELIVERY_POINT	PLACEKEY	22g-222@5yv-jbz-h89	PARENT	None	None
# */
# Invoking: `sql_db_query_checker` with `{'query': "SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG FROM dol WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' OR LEGAL_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;"}`
# responded: The relevant tables for querying references to "HSG, LLC" are `dol`, `ppp`, and `sg`. The columns that may contain the business name are `BUSINESS_NAME_ORG` in both the `dol` and `ppp` tables, and `LOCATION_NAME_ORG` in the `sg` table.
#
# I will create queries to search for "HSG, LLC" in these columns across the three tables.
#
# Here are the queries I will run:
#
# 1. For the `dol` table:
#    ```sql
#    SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG FROM dol WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' OR LEGAL_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;
#    ```
#
# 2. For the `ppp` table:
#    ```sql
#    SELECT BUSINESS_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE, BUSINESS_ADDR_POSTAL_CODE FROM ppp WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;
#    ```
#
# 3. For the `sg` table:
#    ```sql
#    SELECT LOCATION_NAME_ORG, BUSINESS_ADDR_FULL FROM sg WHERE LOCATION_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;
#    ```
#
# I will check these queries for correctness before executing them.
#
# ```sql
# SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG FROM dol WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' OR LEGAL_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;
# ```
# Invoking: `sql_db_query_checker` with `{'query': "SELECT BUSINESS_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE, BUSINESS_ADDR_POSTAL_CODE FROM ppp WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;"}`
# responded: The relevant tables for querying references to "HSG, LLC" are `dol`, `ppp`, and `sg`. The columns that may contain the business name are `BUSINESS_NAME_ORG` in both the `dol` and `ppp` tables, and `LOCATION_NAME_ORG` in the `sg` table.
#
# I will create queries to search for "HSG, LLC" in these columns across the three tables.
#
# Here are the queries I will run:
#
# 1. For the `dol` table:
#    ```sql
#    SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG FROM dol WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' OR LEGAL_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;
#    ```
#
# 2. For the `ppp` table:
#    ```sql
#    SELECT BUSINESS_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE, BUSINESS_ADDR_POSTAL_CODE FROM ppp WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;
#    ```
#
# 3. For the `sg` table:
#    ```sql
#    SELECT LOCATION_NAME_ORG, BUSINESS_ADDR_FULL FROM sg WHERE LOCATION_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;
#    ```
#
# I will check these queries for correctness before executing them.
#
# ```sql
# SELECT BUSINESS_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE, BUSINESS_ADDR_POSTAL_CODE FROM ppp WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;
# ```
# Invoking: `sql_db_query_checker` with `{'query': "SELECT LOCATION_NAME_ORG, BUSINESS_ADDR_FULL FROM sg WHERE LOCATION_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;"}`
# responded: The relevant tables for querying references to "HSG, LLC" are `dol`, `ppp`, and `sg`. The columns that may contain the business name are `BUSINESS_NAME_ORG` in both the `dol` and `ppp` tables, and `LOCATION_NAME_ORG` in the `sg` table.
#
# I will create queries to search for "HSG, LLC" in these columns across the three tables.
#
# Here are the queries I will run:
#
# 1. For the `dol` table:
#    ```sql
#    SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG FROM dol WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' OR LEGAL_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;
#    ```
#
# 2. For the `ppp` table:
#    ```sql
#    SELECT BUSINESS_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE, BUSINESS_ADDR_POSTAL_CODE FROM ppp WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;
#    ```
#
# 3. For the `sg` table:
#    ```sql
#    SELECT LOCATION_NAME_ORG, BUSINESS_ADDR_FULL FROM sg WHERE LOCATION_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;
#    ```
#
# I will check these queries for correctness before executing them.
#
# ```sql
# SELECT LOCATION_NAME_ORG, BUSINESS_ADDR_FULL FROM sg WHERE LOCATION_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG FROM dol WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' OR LEGAL_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;"}`
#
#
# [('HSG, LLC', 'HSG, LLC')]
# Invoking: `sql_db_query` with `{'query': "SELECT BUSINESS_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE, BUSINESS_ADDR_POSTAL_CODE FROM ppp WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;"}`
#
#
# [('HSG, LLC', '4001 S. Decatur Blvd. #37-376', 'LAS VEGAS', 'NV', '89103')]
# Invoking: `sql_db_query` with `{'query': "SELECT LOCATION_NAME_ORG, BUSINESS_ADDR_FULL FROM sg WHERE LOCATION_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;"}`
#
#
# Here are the references to "HSG, LLC" found in the database:
#
# 1. From the `dol` table:
#    - **Business Name:** HSG, LLC
#    - **Legal Name:** HSG, LLC
#
# 2. From the `ppp` table:
#    - **Business Name:** HSG, LLC
#    - **Address:** 4001 S. Decatur Blvd. #37-376, LAS VEGAS, NV 89103
#
# There were no references found in the `sg` table.
#
# > Finished chain.
# {'input': 'find all references to HSG, LLC',
#  'output': 'Here are the references to "HSG, LLC" found in the database:\n\n1. From the `dol` table:\n   - **Business Name:** HSG, LLC\n   - **Legal Name:** HSG, LLC\n\n2. From the `ppp` table:\n   - **Business Name:** HSG, LLC\n   - **Address:** 4001 S. Decatur Blvd. #37-376, LAS VEGAS, NV 89103\n\nThere were no references found in the `sg` table.'}

# %% [markdown]
# ### Some details about this
#
# So I looked and it turns out that 4001 South Decatur Blvd is a strip mall.  And it just so happens that Suite 37 is a UPS Store, which means that this is probably a company with a PO box in that store.  In fact, if you search you will find that there are several businesses in this data set with the same address.  However, interesting things happen if you look at this entry within `G2Explorer.py`.  (See the blog post for that!)
